# %%
import h5py
import numpy as np
import os

# %%
data_path = "/sdf/data/lcls/ds/prj/prjs2e21/results/COOKIE_ML_Output/denoising/run_09032024_multiPulse_final/outputs_fromEvenDist/inference_results/"
files = os.listdir(data_path)
print(files)
# Out:
# ['testAutoencoder_inference_results.txt', 'testAutoencoder_inference_results.h5']
